# %%
from __future__ import print_function
import os.path
from pyspark.sql.functions import split
import sys
from operator import add
from pyspark.sql import SparkSession
from pyspark import SparkContext

filename = "/FileStore/tables/cities.csv"

fileRDD = sc.textFile(filename)
#print(fileRDD.collect())

if filename.endswith(".txt"):
   splitit=" "
else:
   splitit=","
fileWordsRDD = fileRDD.flatMap(lambda line: line.split(splitit))
#for element in fileWordsRDD.collect():
#  print(element)
#print(fileWordsRDD.count())

def wordCount(wordListRDD):
    occurance=wordListRDD.map(lambda x: (x, 1)).reduceByKey(lambda x, y: x + y)
    return occurance

newWord=fileWordsRDD
wordsCounter = wordCount(newWord)
#print(wordsCounter.collect())

wordAre = wordsCounter.sortBy(lambda x: -x[1])
#print(wordAre.collect())
print("Word\t\tNumber of Occurances")
for (element, counter) in wordAre.collect():
  print("%s\t\t\t%i" % (element, counter))
#print(wordAre.persist().is_cached)
wordAre.count()
print(wordAre.count())
#wordAre.saveAsTextFile("/FileStore/tables/foundwords.txt")
# Out:
# Word		Number of Occurances
# U.S.			6
# France			4
# Canada			4
# Germany			3
# Italy			3
# Japan			3
# Norway			2
# Russia			2
# city_id			1
# country			1
# 1			1
# Athens			1
# Greece			1
# Netherlands			1
# 4			1
# Belgium			1
# Atlanta			1
# Barcelona			1
# Beijing			1
# China			1
# 8			1
# 9			1
# 10			1
# Chamonix			1
# 12			1
# Grenoble			1
# 14			1
# Helsinki			1
# Finland			1
# Innsbruck			1
# Austria			1
# 16			1
# Lake Placid			1
# 17			1
# 19			1
# Los Angeles			1
# 20			1
# 21			1
# Mexico City			1
# Mexico			1
# 22			1
# Moskva			1
# 24			1
# 26			1
# Rio de Janeiro			1
# Brazil			1
# 29			1
# Salt Lake City			1
# Switzerland			1
# Sapporo			1
# 33			1
# Sarajevo			1
# 34			1
# South Korea			1
# Sochi			1
# St. Louis			1
# Sydney			1
# Australia			1
# 40			1
# Torino			1
# city			1
# 2			1
# Albertville			1
# 3			1
# Amsterdam			1
# Antwerpen			1
# 5			1
# 6			1
# Spain			1
# 7			1
# Berlin			1
# Calgary			1
# 11			1
# Cortina d'Ampezzo			1
# Garmisch-Partenkirchen			1
# 13			1
# 15			1
# Lillehammer			1
# 18			1
# London			1
# UK			1
# Melbourne			1
# Montreal			1
# 23			1
# Munich			1
# 25			1
# Nagano			1
# Oslo			1
# 27			1
# Paris			1
# 28			1
# Roma			1
# 30			1
# 31			1
# Sankt Moritz			1
# 32			1
# Bosnia and Herzegovina			1
# Seoul			1
# 35			1
# 36			1
# Squaw Valley			1
# 37			1
# 38			1
# Stockholm			1
# Sweden			1
# 39			1
# Tokyo			1
# 41			1
# 42			1
# Vancouver			1
# 110

# %%
print(wordAre.count())
print(wordAre.collect())
# Out:
# 110
# [('U.S.', 6), ('France', 4), ('Canada', 4), ('Germany', 3), ('Italy', 3), ('Japan', 3), ('Norway', 2), ('Russia', 2), ('city_id', 1), ('country', 1), ('1', 1), ('Athens', 1), ('Greece', 1), ('Netherlands', 1), ('4', 1), ('Belgium', 1), ('Atlanta', 1), ('Barcelona', 1), ('Beijing', 1), ('China', 1), ('8', 1), ('9', 1), ('10', 1), ('Chamonix', 1), ('12', 1), ('Grenoble', 1), ('14', 1), ('Helsinki', 1), ('Finland', 1), ('Innsbruck', 1), ('Austria', 1), ('16', 1), ('Lake Placid', 1), ('17', 1), ('19', 1), ('Los Angeles', 1), ('20', 1), ('21', 1), ('Mexico City', 1), ('Mexico', 1), ('22', 1), ('Moskva', 1), ('24', 1), ('26', 1), ('Rio de Janeiro', 1), ('Brazil', 1), ('29', 1), ('Salt Lake City', 1), ('Switzerland', 1), ('Sapporo', 1), ('33', 1), ('Sarajevo', 1), ('34', 1), ('South Korea', 1), ('Sochi', 1), ('St. Louis', 1), ('Sydney', 1), ('Australia', 1), ('40', 1), ('Torino', 1), ('city', 1), ('2', 1), ('Albertville', 1), ('3', 1), ('Amsterdam', 1), ('Antwerpen', 1), ('5', 1), ('6', 1), ('Spain', 1), ('7', 1), ('Berlin', 1), ('Calgary', 1), ('11', 1), ("Cortina d'Ampezzo", 1), ('Garmisch-Partenkirchen', 1), ('13', 1), ('15', 1), ('Lillehammer', 1), ('18', 1), ('London', 1), ('UK', 1), ('Melbourne', 1), ('Montreal', 1), ('23', 1), ('Munich', 1), ('25', 1), ('Nagano', 1), ('Oslo', 1), ('27', 1), ('Paris', 1), ('28', 1), ('Roma', 1), ('30', 1), ('31', 1), ('Sankt Moritz', 1), ('32', 1), ('Bosnia and Herzegovina', 1), ('Seoul', 1), ('35', 1), ('36', 1), ('Squaw Valley', 1), ('37', 1), ('38', 1), ('Stockholm', 1), ('Sweden', 1), ('39', 1), ('Tokyo', 1), ('41', 1), ('42', 1), ('Vancouver', 1)]

# %%
wordsDF = wordAre.toDF()
newDFIs=wordsDF.withColumnRenamed("_1", "Word").withColumnRenamed("_2", "Occurance")
newDFIs.show(wordsDF.count())
# Out:
# +------------+---------+
# |        Word|Occurance|
# +------------+---------+
# |         his|       10|
# |         the|       10|
# |         not|        9|
# |       shall|        8|
# |          in|        7|
# |         And|        7|
# |        that|        7|
# |          my|        7|
# |         and|        7|
# |           I|        7|
# |          we|        6|
# |          of|        6|
# |          he|        6|
# |          to|        6|
# |          be|        6|
# |        this|        5|
# |         But|        4|
# |        That|        4|
# |         one|        4|
# |         man|        4|
# |        with|        4|
# |         day|        4|
# |          do|        3|
# |       would|        3|
# |          is|        3|
# |         men|        3|
# |          if|        3|
# |        wish|        3|
# |          me|        3|
# |           a|        3|
# |        This|        3|
# |         now|        2|
# |          no|        2|
# |         are|        2|
# |       share|        2|
# |       God's|        2|
# |          am|        2|
# |        upon|        2|
# |         die|        2|
# |       feast|        2|
# |        Will|        2|
# |         say|        2|
# |        Then|        2|
# |   Crispin's|        2|
# |       ne'er|        2|
# |         had|        2|
# |     England|        2|
# |         No,|        2|
# |         our|        2|
# |         for|        2|
# |          it|        2|
# |        from|        2|
# |          so|        2|
# |         For|        2|
# |         him|        2|
# |          We|        2|
# |   Crispian.|        2|
# |          He|        2|
# |        day,|        2|
# |          on|        2|
# |       Saint|        2|
# |        day.|        2|
# |       their|        2|
# |        few,|        2|
# |       Shall|        2|
# |WESTMORLAND.|        1|
# |           O|        1|
# |         ten|        1|
# |    thousand|        1|
# |        work|        1|
# |            |        1|
# |      What's|        1|
# |      wishes|        1|
# |     cousin,|        1|
# |Westmorland?|        1|
# |     cousin;|        1|
# |     country|        1|
# |       loss;|        1|
# |       live,|        1|
# |         The|        1|
# |       fewer|        1|
# |        men,|        1|
# |     honour.|        1|
# |        pray|        1|
# |       thee,|        1|
# |    covetous|        1|
# |       gold,|        1|
# |        doth|        1|
# |        feed|        1|
# |       cost;|        1|
# |          It|        1|
# |    garments|        1|
# |       wear;|        1|
# |        Such|        1|
# |      things|        1|
# |       dwell|        1|
# |    desires.|        1|
# |       covet|        1|
# |     honour,|        1|
# |   offending|        1|
# |      alive.|        1|
# |      faith,|        1|
# |    England.|        1|
# |        lose|        1|
# |          an|        1|
# |      honour|        1|
# |        more|        1|
# |    methinks|        1|
# |        best|        1|
# |       have.|        1|
# |         it,|        1|
# |Westmorland,|        1|
# |       host,|        1|
# |      fight,|        1|
# |         Let|        1|
# |     depart;|        1|
# |      convoy|        1|
# |         put|        1|
# |        into|        1|
# |  fellowship|        1|
# |        safe|        1|
# |       stand|        1|
# |     tip-toe|        1|
# |        when|        1|
# |       rouse|        1|
# |          at|        1|
# |        name|        1|
# |        live|        1|
# |        age,|        1|
# |  Crispian."|        1|
# |      scars,|        1|
# |      "These|        1|
# |         Old|        1|
# |         yet|        1|
# |        What|        1|
# |       feats|        1|
# |      names,|        1|
# |    Familiar|        1|
# |       mouth|        1|
# |          as|        1|
# |      words—|        1|
# |       King,|        1|
# |     Exeter,|        1|
# |   Salisbury|        1|
# | Gloucester—|        1|
# |        cups|        1|
# |       story|        1|
# |        good|        1|
# |    Crispian|        1|
# |          go|        1|
# |         by,|        1|
# |      world,|        1|
# |        band|        1|
# |       sheds|        1|
# |      gentle|        1|
# |  condition;|        1|
# |   gentlemen|        1|
# |       think|        1|
# |  themselves|        1|
# |       here,|        1|
# |    manhoods|        1|
# |      speaks|        1|
# |          us|        1|
# |        here|        1|
# |       those|        1|
# |     to-day!|        1|
# |       KING.|        1|
# |         so?|        1|
# |          My|        1|
# |        fair|        1|
# |          If|        1|
# |      mark'd|        1|
# |        die,|        1|
# |      enough|        1|
# |          To|        1|
# |     greater|        1|
# |       will!|        1|
# |       more.|        1|
# |          By|        1|
# |       Jove,|        1|
# |         Nor|        1|
# |        care|        1|
# |         who|        1|
# |      yearns|        1|
# |     outward|        1|
# |         sin|        1|
# |        most|        1|
# |        soul|        1|
# |        coz,|        1|
# |      peace!|        1|
# |       great|        1|
# |          As|        1|
# |        hope|        1|
# |          O,|        1|
# |       more!|        1|
# |      Rather|        1|
# |    proclaim|        1|
# |     through|        1|
# |       which|        1|
# |        hath|        1|
# |     stomach|        1|
# |    passport|        1|
# |       made,|        1|
# |      crowns|        1|
# |      purse;|        1|
# |       man's|        1|
# |     company|        1|
# |       fears|        1|
# |         us.|        1|
# |      call'd|        1|
# |    outlives|        1|
# |       comes|        1|
# |       home,|        1|
# |      nam'd,|        1|
# |         see|        1|
# |         old|        1|
# |      yearly|        1|
# |       vigil|        1|
# | neighbours,|        1|
# |  "To-morrow|        1|
# |        will|        1|
# |       strip|        1|
# |      sleeve|        1|
# |        show|        1|
# |      wounds|        1|
# |       day."|        1|
# |     forget;|        1|
# |         all|        1|
# |     forgot,|        1|
# |       he'll|        1|
# |   remember,|        1|
# | advantages,|        1|
# |         did|        1|
# |   household|        1|
# |       Harry|        1|
# |     Bedford|        1|
# |     Warwick|        1|
# |     Talbot,|        1|
# |          Be|        1|
# |     flowing|        1|
# |     freshly|        1|
# | rememb'red.|        1|
# |       teach|        1|
# |        son;|        1|
# |     Crispin|        1|
# |        From|        1|
# |      ending|        1|
# | rememberèd—|        1|
# |       happy|        1|
# |   brothers;|        1|
# |      to-day|        1|
# |       blood|        1|
# |    brother;|        1|
# |       vile,|        1|
# |       a-bed|        1|
# |    accurs'd|        1|
# |        they|        1|
# |        were|        1|
# |        hold|        1|
# |       cheap|        1|
# |      whiles|        1|
# |         any|        1|
# |      fought|        1|
# +------------+---------+

# %%
wordAre.toDebugString
# Out:
# Out[25]: <bound method RDD.toDebugString of PythonRDD[1362] at collect at <command-3065228375621183>:34>

# %%
filename = "/FileStore/tables/foundwords.txt/part-00000"



fileRDD = sc.textFile(filename)
print(fileRDD.collect())
# Out:
# ["('his', 10)", "('the', 10)", "('not', 9)", "('shall', 8)", "('in', 7)", "('And', 7)", "('that', 7)", "('my', 7)", "('and', 7)", "('I', 7)", "('we', 6)", "('of', 6)", "('he', 6)", "('to', 6)", "('be', 6)", "('this', 5)", "('But', 4)", "('That', 4)", "('one', 4)", "('man', 4)", "('with', 4)", "('day', 4)", "('do', 3)", "('would', 3)", "('is', 3)", "('men', 3)", "('if', 3)", "('wish', 3)", "('me', 3)", "('a', 3)", "('This', 3)", "('now', 2)", "('no', 2)", "('are', 2)", "('share', 2)", '("God\'s", 2)', "('am', 2)", "('upon', 2)", "('die', 2)", "('feast', 2)", "('Will', 2)", "('say', 2)", "('Then', 2)", '("Crispin\'s", 2)', '("ne\'er", 2)', "('had', 2)", "('England', 2)", "('No,', 2)", "('our', 2)", "('for', 2)", "('it', 2)", "('from', 2)", "('so', 2)", "('For', 2)", "('him', 2)", "('We', 2)", "('Crispian.', 2)", "('He', 2)", "('day,', 2)", "('on', 2)", "('Saint', 2)", "('day.', 2)", "('their', 2)", "('few,', 2)", "('Shall', 2)", "('WESTMORLAND.', 1)", "('O', 1)", "('ten', 1)", "('thousand', 1)", "('work', 1)", "('', 1)", '("What\'s", 1)', "('wishes', 1)", "('cousin,', 1)", "('Westmorland?', 1)", "('cousin;', 1)", "('country', 1)", "('loss;', 1)", "('live,', 1)", "('The', 1)", "('fewer', 1)", "('men,', 1)", "('honour.', 1)", "('pray', 1)", "('thee,', 1)", "('covetous', 1)", "('gold,', 1)", "('doth', 1)", "('feed', 1)", "('cost;', 1)", "('It', 1)", "('garments', 1)", "('wear;', 1)", "('Such', 1)", "('things', 1)", "('dwell', 1)", "('desires.', 1)", "('covet', 1)", "('honour,', 1)", "('offending', 1)", "('alive.', 1)", "('faith,', 1)", "('England.', 1)", "('lose', 1)", "('an', 1)", "('honour', 1)", "('more', 1)", "('methinks', 1)", "('best', 1)", "('have.', 1)", "('it,', 1)", "('Westmorland,', 1)", "('host,', 1)", "('fight,', 1)", "('Let', 1)", "('depart;', 1)", "('convoy', 1)", "('put', 1)", "('into', 1)", "('fellowship', 1)", "('safe', 1)", "('stand', 1)", "('tip-toe', 1)", "('when', 1)", "('rouse', 1)", "('at', 1)", "('name', 1)", "('live', 1)", "('age,', 1)", '(\'Crispian."\', 1)', "('scars,', 1)", '(\'"These\', 1)', "('Old', 1)", "('yet', 1)", "('What', 1)", "('feats', 1)", "('names,', 1)", "('Familiar', 1)", "('mouth', 1)", "('as', 1)", "('words—', 1)", "('King,', 1)", "('Exeter,', 1)", "('Salisbury', 1)", "('Gloucester—', 1)", "('cups', 1)", "('story', 1)", "('good', 1)", "('Crispian', 1)", "('go', 1)", "('by,', 1)", "('world,', 1)", "('band', 1)", "('sheds', 1)", "('gentle', 1)", "('condition;', 1)", "('gentlemen', 1)", "('think', 1)", "('themselves', 1)", "('here,', 1)", "('manhoods', 1)", "('speaks', 1)", "('us', 1)", "('here', 1)", "('those', 1)", "('to-day!', 1)", "('KING.', 1)", "('so?', 1)", "('My', 1)", "('fair', 1)", "('If', 1)", '("mark\'d", 1)', "('die,', 1)", "('enough', 1)", "('To', 1)", "('greater', 1)", "('will!', 1)", "('more.', 1)", "('By', 1)", "('Jove,', 1)", "('Nor', 1)", "('care', 1)", "('who', 1)", "('yearns', 1)", "('outward', 1)", "('sin', 1)", "('most', 1)", "('soul', 1)", "('coz,', 1)", "('peace!', 1)", "('great', 1)", "('As', 1)", "('hope', 1)", "('O,', 1)", "('more!', 1)", "('Rather', 1)", "('proclaim', 1)", "('through', 1)", "('which', 1)", "('hath', 1)", "('stomach', 1)", "('passport', 1)", "('made,', 1)", "('crowns', 1)", "('purse;', 1)", '("man\'s", 1)', "('company', 1)", "('fears', 1)", "('us.', 1)", '("call\'d", 1)', "('outlives', 1)", "('comes', 1)", "('home,', 1)", '("nam\'d,", 1)', "('see', 1)", "('old', 1)", "('yearly', 1)", "('vigil', 1)", "('neighbours,', 1)", '(\'"To-morrow\', 1)', "('will', 1)", "('strip', 1)", "('sleeve', 1)", "('show', 1)", "('wounds', 1)", '(\'day."\', 1)', "('forget;', 1)", "('all', 1)", "('forgot,', 1)", '("he\'ll", 1)', "('remember,', 1)", "('advantages,', 1)", "('did', 1)", "('household', 1)", "('Harry', 1)", "('Bedford', 1)", "('Warwick', 1)", "('Talbot,', 1)", "('Be', 1)", "('flowing', 1)", "('freshly', 1)", '("rememb\'red.", 1)', "('teach', 1)", "('son;', 1)", "('Crispin', 1)", "('From', 1)", "('ending', 1)", "('rememberèd—', 1)", "('happy', 1)", "('brother ...
